# %% [markdown]
# # Does blocking affect the m and u estimates of other columns?
#
# In this notebook I consider whether blocking on a column affects the estimates of `m` and `u` values of other columns.
#
# It shows that blocking _does not_ affect the `m` and `u` estimates of other columns

# %%
from copy import deepcopy
settings = {
    "link_type": "dedupe_only",
    "comparison_columns": [
        {
            "col_name": "col_1",
            "m_probabilities": [0.1, 0.9],  # Probability of typo
            "u_probabilities": [0.3, 0.7],  # Probability of collision
        },
        {
            "col_name": "col_2",
            "m_probabilities": [0.05, 0.95],  # Probability of typo
            "u_probabilities": [0.975, 0.025],  # Probability of collision
        },
        {
            "col_name": "col_3",
            "m_probabilities": [0.2, 0.8],  # Probability of typo
            "u_probabilities": [0.8, 0.2],  # Probability of collision
        },
          {
            "col_name": "col_4",
            "m_probabilities": [0.05, 0.95],  # Probability of typo
            "u_probabilities": [0.9, 0.1],  # Probability of collision
        },
    ],
     "additional_columns_to_retain": [
        "true_match", "true_match_probability"
    ]
}

# %% [markdown]
# The following cell may take a minute or two to compute

# %%
from splink_data_generation.generate_data_exact import generate_df_gammas_exact
from splink_data_generation.match_prob import add_match_prob
from splink_data_generation.log_likelihood import add_log_likelihood
df = generate_df_gammas_exact(settings)
df = add_match_prob(df, settings)
df = add_log_likelihood(df, settings)
cols = [c for c in df.columns if "_r" not in c]
len(df)
# Out:
# /Users/robinlinacre/anaconda3/lib/python3.8/site-packages/splink_data_generation/generate_data_exact.py:130: UserWarning: Note that the proportion_of_matches setting is ignored by this generator. Only the m_probabilities and u_probabilities are observed. The proportion of matches in the generated dataset was 0.500
#   warnings.warn(
# 40000

# %%
df[cols].head()
# Out:
#    gamma_col_1  gamma_col_2  gamma_col_3  gamma_col_4  true_match_l  \
# 0            0            0            0            0             1
# 1            0            1            0            0             1
# 2            0            1            0            0             1
# 3            0            1            0            0             1
# 4            0            1            0            0             1
#
#   unique_id_l  true_match_probability_l  true_log_likelihood_l
# 0    802e7a59                  0.000237              -2.250704
# 1    8c5454e0                  0.149606              -5.752448
# 2    c958e689                  0.149606              -5.752448
# 3    d2f9233c                  0.149606              -5.752448
# 4    5c03633b                  0.149606              -5.752448

# %% [markdown]
# ## Does Splink correctly estimate `m` and `u` values for the whole dataset?

# %%
import logging 
logging.basicConfig()  # Means logs will print in Jupyter Lab

# Set to DEBUG if you want splink to log the SQL statements it's executing under the hood
logging.getLogger("splink").setLevel(logging.INFO)

from pyspark.context import SparkContext
from pyspark.sql import SparkSession
sc = SparkContext.getOrCreate()
spark = SparkSession(sc)

# %%
# Now use Splink to estimate the params from the data
from splink_data_generation.estimate_splink import estimate

settings = {
    "link_type": "dedupe_only",
    "comparison_columns": [
        {
            "col_name": "col_1",

        },
        {
            "col_name": "col_2",
       
        },
        {
            "col_name": "col_3",

        },
          {
            "col_name": "col_4",

        },
    ],
     "additional_columns_to_retain": [
        "true_match", "true_match_probability"
    ]
}

df_e, linker = estimate(df, deepcopy(settings) ,spark)
df_e.toPandas().head(5)
# Out:
# /Users/robinlinacre/anaconda3/lib/python3.8/site-packages/splink/case_statements.py:17: UserWarning: The jaro_winkler_sim user definined function is not available in Spark Or you did not pass 'spark' (the SparkSession) into 'Params' Falling back to using levenshtein in the default string comparison functions You can import these functions using the scala-udf-similarity-0.0.6.jar provided with Splink
#   warnings.warn(f"The jaro_winkler_sim user definined function is not available in Spark "
# INFO:splink.expectation_step:Log likelihood for iteration 0:  -106324.89547299672
# INFO:splink.iterate:Iteration 0 complete
# INFO:splink.params:The maximum change in parameters was 0.5681762337684632 for key π_gamma_col_1_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 1:  -81393.5722664337
# INFO:splink.iterate:Iteration 1 complete
# INFO:splink.params:The maximum change in parameters was 0.030521035194396973 for key π_gamma_col_2_prob_dist_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 2:  -80818.52456855273
# INFO:splink.iterate:Iteration 2 complete
# INFO:splink.params:The maximum change in parameters was 0.010583415627479553 for key π_gamma_col_2_prob_dist_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 3:  -80771.77780874836
# INFO:splink.iterate:Iteration 3 complete
# INFO:splink.params:The maximum change in parameters was 0.004878949373960495 for key π_gamma_col_2_prob_dist_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 4:  -80761.10035948093
# INFO:splink.iterate:Iteration 4 complete
# INFO:splink.params:The maximum change in parameters was 0.0029280781745910645 for key π_gamma_col_2_prob_dist_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 5:  -80756.6756372544
# INFO:splink.iterate:Iteration 5 complete
# INFO:splink.params:The maximum change in parameters was 0.0018998980522155762 for key π_gamma_col_2_prob_dist_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 6:  -80754.71696658104
# INFO:splink.iterate:Iteration 6 complete
# INFO:splink.params:The maximum change in parameters was 0.001262083649635315 for key π_gamma_col_2_prob_dist_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 7:  -80753.82753813591
# INFO:splink.iterate:Iteration 7 complete
# INFO:splink.params:The maximum change in parameters was 0.0008482523262500763 for key π_gamma_col_2_prob_dist_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 8:  -80753.41436320808
# INFO:splink.iterate:Iteration 8 complete
# INFO:splink.params:The maximum change in parameters was 0.0005748271942138672 for key π_gamma_col_2_prob_dist_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 9:  -80753.22042534321
# INFO:splink.iterate:Iteration 9 complete
# INFO:splink.params:The maximum change in parameters was 0.00039201974868774414 for key π_gamma_col_2_prob_dist_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 10:  -80753.12626945847
# INFO:splink.iterate:Iteration 10 complete
# INFO:splink.params:The maximum change in parameters was 0.0002687312662601471 for key π_gamma_col_2_prob_dist_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 11:  -80753.07961376834
# INFO:splink.iterate:Iteration 11 complete
# INFO:splink.params:The maximum change in parameters was 0.00018502026796340942 for key π_gamma_col_2_prob_dist_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 12:  -80753.05716929582
# INFO:splink.iterate:Iteration 12 complete
# INFO:splink.params:The maximum change in parameters was 0.0001278519630432129 for key π_gamma_col_2_prob_dist_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 13:  -80753.04503260525
# INFO:splink.iterate:Iteration 13 complete
# INFO:splink.params:The maximum change in parameters was 8.863583207130432e-05 for key π_gamma_col_2_prob_dist_match_level_0_probability
# INFO:splink.iterate:EM algorithm has converged
# INFO:splink.expectation_step:Log likelihood for iteration 14:  -80753.04115782099
#    match_probability unique_id_l unique_id_r  gamma_col_1  \
# 0           0.000239    802e7a59    277be987            0
# 1           0.150257    8c5454e0    84743376            0
# 2           0.150257    c958e689    4de84e42            0
# 3           0.150257    d2f9233c    154cb47d            0
# 4           0.150257    5c03633b    2272039d            0
#
#    prob_gamma_col_1_non_match  prob_gamma_col_1_match  gamma_col_2  \
# 0                     0.30004                0.100021            0
# 1                     0.30004                0.100021            1
# 2                     0.30004                0.100021            1
# 3                     0.30004                0.100021            1
# 4                     0.30004                0.100021            1
#
#    prob_gamma_col_2_non_match  prob_gamma_col_2_match  gamma_col_3  \
# 0                    0.975078                0.050206            0
# 1                    0.024922                0.949794            0
# 2                    0.024922                0.949794            0
# 3                    0.024922                0.949794            0
# 4                    0.024922                0.949794            0
#
#    prob_gamma_col_3_non_match  prob_gamma_col_3_match  gamma_col_4  \
# 0                    0.800106                0.200078            0
# 1                    0.800106                0.200078            0
# 2                    0.800106                0.200078            0
# 3                    0.800106                0.200078            0
# 4                    0.800106                0.200078            0
#
#    prob_gamma_col_4_non_match  prob_gamma_col_4_match  true_match_l  \
# 0                    0.900187                0.050073             1
# 1                    0.900187                0.050073             1
# 2                    0.900187                0.050073             1
# 3                    0.900187                0.050073             1
# 4                    0.900187                0.050073             1
#
#    true_match_r  true_match_probability_l  true_match_probability_r
# 0             1                  0.000237                  0.000237
# 1             1                  0.149606                  0.149606
# 2             1                  0.149606                  0.149606
# 3             1                  0.149606                  0.149606
# 4             1                  0.149606                  0.149606

# %%
linker.params
# Out:
# λ (proportion of matches) = 0.5001532435417175
# ------------------------------------
# gamma_col_1: Comparison of col_1
#
# Probability distribution of gamma values amongst matches:
#     value 0: 0.100021 (level represents lowest category of string similarity)
#     value 1: 0.899979 (level represents highest category of string similarity)
#
# Probability distribution of gamma values amongst non-matches:
#     value 0: 0.300040 (level represents lowest category of string similarity)
#     value 1: 0.699960 (level represents highest category of string similarity)
# ------------------------------------
# gamma_col_2: Comparison of col_2
#
# Probability distribution of gamma values amongst matches:
#     value 0: 0.050206 (level represents lowest category of string similarity)
#     value 1: 0.949794 (level represents highest category of string similarity)
#
# Probability distribution of gamma values amongst non-matches:
#     value 0: 0.975078 (level represents lowest category of string similarity)
#     value 1: 0.024922 (level represents highest category of string similarity)
# ------------------------------------
# gamma_col_3: Comparison of col_3
#
# Probability distribution of gamma values amongst matches:
#     value 0: 0.200078 (level represents lowest category of string similarity)
#     value 1: 0.799922 (level represents highest category of string similarity)
#
# Probability distribution of gamma values amongst non-matches:
#     value 0: 0.800106 (level represents lowest category of string similarity)
#     value 1: 0.199894 (level represents highest category of string similarity)
# ------------------------------------
# gamma_col_4: Comparison of col_4
#
# Probability distribution of gamma values amongst matches:
#     value 0: 0.050073 (level represents lowest category of string similarity)
#     value 1: 0.949927 (level represents highest category of string similarity)
#
# Probability distribution of gamma values amongst non-matches:
#     value 0: 0.900187 (level represents lowest category of string similarity)
#     value 1: 0.099813 (level represents highest category of string similarity)

# %% [markdown]
# ## Estimating parameters on blocked data
#
# Splink has correctly estiamted parameters for the full dataset.
#
# How about if we blocked on column 1.
#
# Note this is equivalent to filtering the dataset down to only rows where `gamma_col_1 = 1`

# %%
df_col_1 = df[df["gamma_col_1"] == 1]

# %%
settings = {
    "link_type": "dedupe_only",
    "comparison_columns": [
        {
            "col_name": "col_2",
       
        },
        {
            "col_name": "col_3",

        },
          {
            "col_name": "col_4",

        },
    ],
    "max_iterations": 200,
    "em_convergence": 0.0001,
     "additional_columns_to_retain": [
        "true_match", "true_match_probability"
    ]
}

df_e, linker = estimate(df_col_1, deepcopy(settings) ,spark)
df_e.toPandas().head(5)
# Out:
# /Users/robinlinacre/anaconda3/lib/python3.8/site-packages/splink/case_statements.py:17: UserWarning: The jaro_winkler_sim user definined function is not available in Spark Or you did not pass 'spark' (the SparkSession) into 'Params' Falling back to using levenshtein in the default string comparison functions You can import these functions using the scala-udf-similarity-0.0.6.jar provided with Splink
#   warnings.warn(f"The jaro_winkler_sim user definined function is not available in Spark "
# INFO:splink.expectation_step:Log likelihood for iteration 0:  -55502.610051441974
# INFO:splink.iterate:Iteration 0 complete
# INFO:splink.params:The maximum change in parameters was 0.08619900941848757 for key π_gamma_col_3_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 1:  -49623.716720507335
# INFO:splink.iterate:Iteration 1 complete
# INFO:splink.params:The maximum change in parameters was 0.031153202056884766 for key π_gamma_col_2_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 2:  -49299.89222942199
# INFO:splink.iterate:Iteration 2 complete
# INFO:splink.params:The maximum change in parameters was 0.011668406426906586 for key π_gamma_col_2_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 3:  -49254.70688829544
# INFO:splink.iterate:Iteration 3 complete
# INFO:splink.params:The maximum change in parameters was 0.005676984786987305 for key π_gamma_col_2_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 4:  -49238.57333640922
# INFO:splink.iterate:Iteration 4 complete
# INFO:splink.params:The maximum change in parameters was 0.0035570859909057617 for key π_gamma_col_2_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 5:  -49230.570210324964
# INFO:splink.iterate:Iteration 5 complete
# INFO:splink.params:The maximum change in parameters was 0.002407517284154892 for key π_gamma_col_2_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 6:  -49226.459442604515
# INFO:splink.iterate:Iteration 6 complete
# INFO:splink.params:The maximum change in parameters was 0.001674732193350792 for key π_gamma_col_2_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 7:  -49224.30443184191
# INFO:splink.iterate:Iteration 7 complete
# INFO:splink.params:The maximum change in parameters was 0.001185661181807518 for key π_gamma_col_2_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 8:  -49223.15367439559
# INFO:splink.iterate:Iteration 8 complete
# INFO:splink.params:The maximum change in parameters was 0.0008512735366821289 for key π_gamma_col_2_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 9:  -49222.52785035171
# INFO:splink.iterate:Iteration 9 complete
# INFO:splink.params:The maximum change in parameters was 0.0006179995834827423 for key π_gamma_col_2_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 10:  -49222.186251391926
# INFO:splink.iterate:Iteration 10 complete
# INFO:splink.params:The maximum change in parameters was 0.0004526376724243164 for key π_gamma_col_2_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 11:  -49221.9955953454
# INFO:splink.iterate:Iteration 11 complete
# INFO:splink.params:The maximum change in parameters was 0.00033370964229106903 for key π_gamma_col_2_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 12:  -49221.89245185019
# INFO:splink.iterate:Iteration 12 complete
# INFO:splink.params:The maximum change in parameters was 0.00024730339646339417 for key π_gamma_col_2_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 13:  -49221.83351907844
# INFO:splink.iterate:Iteration 13 complete
# INFO:splink.params:The maximum change in parameters was 0.00018399953842163086 for key π_gamma_col_2_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 14:  -49221.79990697837
# INFO:splink.iterate:Iteration 14 complete
# INFO:splink.params:The maximum change in parameters was 0.0001372694969177246 for key π_gamma_col_2_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 15:  -49221.78235406437
# INFO:splink.iterate:Iteration 15 complete
# INFO:splink.params:The maximum change in parameters was 0.00010261125862598419 for key π_gamma_col_2_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 16:  -49221.7720541695
# INFO:splink.iterate:Iteration 16 complete
# INFO:splink.params:The maximum change in parameters was 7.683411240577698e-05 for key π_gamma_col_2_prob_dist_non_match_level_1_probability
# INFO:splink.iterate:EM algorithm has converged
# INFO:splink.expectation_step:Log likelihood for iteration 17:  -49221.76665941356
#    match_probability unique_id_l unique_id_r  gamma_col_2  \
# 0           0.000909    eee72f8f    5d5d784e            0
# 1           0.401034    ef1c82f5    dcc0cfb1            1
# 2           0.401034    681a2b34    266bc67e            1
# 3           0.401034    d44c77fc    0bb1223f            1
# 4           0.401034    1546b53f    65d69f7a            1
#
#    prob_gamma_col_2_non_match  prob_gamma_col_2_match  gamma_col_3  \
# 0                    0.974769                0.049861            0
# 1                    0.025231                0.950139            0
# 2                    0.025231                0.950139            0
# 3                    0.025231                0.950139            0
# 4                    0.025231                0.950139            0
#
#    prob_gamma_col_3_non_match  prob_gamma_col_3_match  gamma_col_4  \
# 0                    0.799886                0.199882            0
# 1                    0.799886                0.199882            0
# 2                    0.799886                0.199882            0
# 3                    0.799886                0.199882            0
# 4                    0.799886                0.199882            0
#
#    prob_gamma_col_4_non_match  prob_gamma_col_4_match  true_match_l  \
# 0                    0.899833                0.049837             1
# 1                    0.899833                0.049837             1
# 2                    0.899833                0.049837             1
# 3                    0.899833                0.049837             1
# 4                    0.899833                0.049837             1
#
#    true_match_r  true_match_probability_l  true_match_probability_r
# 0             1                  0.000915                  0.000915
# 1             1                  0.404255                  0.404255
# 2             1                  0.404255                  0.404255
# 3             1                  0.404255                  0.404255
# 4             1                  0.404255                  0.404255

# %%
linker.params
# Out:
# λ (proportion of matches) = 0.5623059868812561
# ------------------------------------
# gamma_col_2: Comparison of col_2
#
# Probability distribution of gamma values amongst matches:
#     value 0: 0.049861 (level represents lowest category of string similarity)
#     value 1: 0.950139 (level represents highest category of string similarity)
#
# Probability distribution of gamma values amongst non-matches:
#     value 0: 0.974769 (level represents lowest category of string similarity)
#     value 1: 0.025231 (level represents highest category of string similarity)
# ------------------------------------
# gamma_col_3: Comparison of col_3
#
# Probability distribution of gamma values amongst matches:
#     value 0: 0.199882 (level represents lowest category of string similarity)
#     value 1: 0.800118 (level represents highest category of string similarity)
#
# Probability distribution of gamma values amongst non-matches:
#     value 0: 0.799886 (level represents lowest category of string similarity)
#     value 1: 0.200114 (level represents highest category of string similarity)
# ------------------------------------
# gamma_col_4: Comparison of col_4
#
# Probability distribution of gamma values amongst matches:
#     value 0: 0.049837 (level represents lowest category of string similarity)
#     value 1: 0.950163 (level represents highest category of string similarity)
#
# Probability distribution of gamma values amongst non-matches:
#     value 0: 0.899833 (level represents lowest category of string similarity)
#     value 1: 0.100167 (level represents highest category of string similarity)

# %% [markdown]
# We see that both the `m` and `u` parameter estimates are correct for the remaining columns on the blocked data
