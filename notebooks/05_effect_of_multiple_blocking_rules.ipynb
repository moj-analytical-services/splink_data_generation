# %% [markdown]
# # What is the effect of multiple blocking rules on `m` and `u` values?
#
# Splink allows the user to specify multiple blocking rules.  When more than one blocking rule is specified, Splink will generate a deduplicated dataset of all record comparisons that obey at least one of the blocking rules.  The Fellegi-Sunter/Expectation Maximisation approach is then used on this combined dataset.
#
# In this notebook, I demonstrate why this can be problematic.
#
# I generate a synthetic dataset with known `m` and `u` values for four comparison columns, `col_1`, `col_2`, `col_3` `col_4`.
#
# I then block on `col_1` or `col_2`, and estimate the paramters of the model.
#
# #### Key findings:
#
# - Blocking on `col_1` or `col_2` and then including them as parameter estimates results in incorrect estimates for _all_columns
# - Blocking on `col_1` or `col_2` and then estimating parameter  estimates for only `col_3` `col_4` results in correct parameter estimates for `col_3` and `col_4`

# %%
from copy import deepcopy
settings = {
    "link_type": "dedupe_only",
    "comparison_columns": [
        {
            "col_name": "col_1",
            "m_probabilities": [0.1, 0.9],  # Probability of typo
            "u_probabilities": [0.95, 0.05],  # Probability of collision
        },
        {
            "col_name": "col_2",
            "m_probabilities": [0.05, 0.95],  # Probability of typo
            "u_probabilities": [0.975, 0.025],  # Probability of collision
        },
        {
            "col_name": "col_3",
            "m_probabilities": [0.2, 0.8],  # Probability of typo
            "u_probabilities": [0.8, 0.2],  # Probability of collision
        },
          {
            "col_name": "col_4",
            "m_probabilities": [0.05, 0.95],  # Probability of typo
            "u_probabilities": [0.9, 0.1],  # Probability of collision
        },
    ],
     "additional_columns_to_retain": [
        "true_match"
    ]
}

# %%
from splink_data_generation.generate_data_exact import generate_df_gammas_exact
df = generate_df_gammas_exact(settings)
cols = [c for c in df.columns if "_r" not in c]
len(df)
# Out:
# /Users/robinlinacre/anaconda3/lib/python3.8/site-packages/splink_data_generation/generate_data_exact.py:130: UserWarning: Note that the proportion_of_matches setting is ignored by this generator. Only the m_probabilities and u_probabilities are observed. The proportion of matches in the generated dataset was 0.333
#   warnings.warn(
# 60000

# %%
df.head()
# Out:
#    gamma_col_1  gamma_col_2  gamma_col_3  gamma_col_4  true_match_l  \
# 0            0            0            0            0             1
# 1            0            1            0            0             1
# 2            0            1            0            0             1
# 3            0            1            0            0             1
# 4            0            1            0            0             1
#
#    true_match_r unique_id_l unique_id_r
# 0             1    17c210b7    23087bd2
# 1             1    cc8e1bf9    02a4c2a1
# 2             1    9ae59505    06450471
# 3             1    0915e334    2f226b72
# 4             1    0463f328    4d161f05

# %% [markdown]
# We can see that in the whole dataset, the assupmption of conditional independence of comparison vector values given match status is true

# %%
import pandas as pd
pd.options.display.float_format = '{:,.4f}'.format
gamma_cols = [c for c in df.columns if 'gamma_' in c]
f1 = df["true_match_l"] == 1
df.loc[f1, gamma_cols].corr()
# Out:
#              gamma_col_1  gamma_col_2  gamma_col_3  gamma_col_4
# gamma_col_1       1.0000       0.0000       0.0000      -0.0000
# gamma_col_2       0.0000       1.0000       0.0000      -0.0000
# gamma_col_3       0.0000       0.0000       1.0000      -0.0000
# gamma_col_4      -0.0000      -0.0000      -0.0000       1.0000

# %%
f2 = df["true_match_l"] == 0
df.loc[f2, gamma_cols].corr()
# Out:
#              gamma_col_1  gamma_col_2  gamma_col_3  gamma_col_4
# gamma_col_1       1.0000      -0.0000       0.0000      -0.0000
# gamma_col_2      -0.0000       1.0000       0.0000       0.0000
# gamma_col_3       0.0000       0.0000       1.0000       0.0000
# gamma_col_4      -0.0000       0.0000       0.0000       1.0000

# %% [markdown]
# This assumption also holds if we block on a single variable (`col_1`):

# %%
block_1 = df["gamma_col_1"] == 1
df.loc[f1&block_1, gamma_cols].corr()
# Out:
#              gamma_col_1  gamma_col_2  gamma_col_3  gamma_col_4
# gamma_col_1          nan          nan          nan          nan
# gamma_col_2          nan       1.0000       0.0000      -0.0000
# gamma_col_3          nan       0.0000       1.0000      -0.0000
# gamma_col_4          nan      -0.0000      -0.0000       1.0000

# %% [markdown]
# However, it no longer holds if we block on two variables:

# %%
block_2 = df["gamma_col_2"] == 1
df_blocked = df[block_1 | block_2]

# %%
f1 = df_blocked["true_match_l"] == 1
df_blocked.loc[f1, gamma_cols].corr()
# Out:
#              gamma_col_1  gamma_col_2  gamma_col_3  gamma_col_4
# gamma_col_1       1.0000      -0.0707       0.0000      -0.0000
# gamma_col_2      -0.0707       1.0000       0.0000       0.0000
# gamma_col_3       0.0000       0.0000       1.0000      -0.0000
# gamma_col_4      -0.0000       0.0000      -0.0000       1.0000

# %%
f1 = df_blocked["true_match_l"] == 0
df_blocked.loc[f1, gamma_cols].corr()
# Out:
#              gamma_col_1  gamma_col_2  gamma_col_3  gamma_col_4
# gamma_col_1       1.0000      -0.9624       0.0000      -0.0000
# gamma_col_2      -0.9624       1.0000       0.0000       0.0000
# gamma_col_3       0.0000       0.0000       1.0000      -0.0000
# gamma_col_4      -0.0000       0.0000      -0.0000       1.0000

# %% [markdown]
# ## What do these correlations (the violation of conditional independence) this mean for the estimation of parameters?

# %% [markdown]
# ### Example 1:  Esimtate all parameters

# %%
import logging 
logging.basicConfig()  # Means logs will print in Jupyter Lab

# Set to DEBUG if you want splink to log the SQL statements it's executing under the hood
logging.getLogger("splink").setLevel(logging.INFO)

from pyspark.context import SparkContext
from pyspark.sql import SparkSession
sc = SparkContext.getOrCreate()
spark = SparkSession(sc)

# %%
from splink_data_generation.estimate_splink import estimate

settings_2 = deepcopy(settings)
settings_2["proportion_of_matches"] = df_blocked["true_match_l"].mean()

df_e, linker = estimate(df_blocked,settings_2,spark)
df_e.toPandas().head(5)
# Out:
# /Users/robinlinacre/anaconda3/lib/python3.8/site-packages/splink/case_statements.py:17: UserWarning: The jaro_winkler_sim user definined function is not available in Spark Or you did not pass 'spark' (the SparkSession) into 'Params' Falling back to using levenshtein in the default string comparison functions You can import these functions using the scala-udf-similarity-0.0.6.jar provided with Splink
#   warnings.warn(f"The jaro_winkler_sim user definined function is not available in Spark "
# INFO:splink.expectation_step:Log likelihood for iteration 0:  -42423.936352907534
# INFO:splink.iterate:Iteration 0 complete
# INFO:splink.params:The maximum change in parameters was 0.6787893295288085 for key π_gamma_col_1_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 1:  -37339.63852485094
# INFO:splink.iterate:Iteration 1 complete
# INFO:splink.params:The maximum change in parameters was 0.03456217050552368 for key π_gamma_col_2_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 2:  -37214.084937776075
# INFO:splink.iterate:Iteration 2 complete
# INFO:splink.params:The maximum change in parameters was 0.02778526395559311 for key π_gamma_col_3_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 3:  -37162.240116894514
# INFO:splink.iterate:Iteration 3 complete
# INFO:splink.params:The maximum change in parameters was 0.022252395749092102 for key π_gamma_col_3_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 4:  -37135.30202303743
# INFO:splink.iterate:Iteration 4 complete
# INFO:splink.params:The maximum change in parameters was 0.01647132635116577 for key π_gamma_col_3_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 5:  -37120.51808206146
# INFO:splink.iterate:Iteration 5 complete
# INFO:splink.params:The maximum change in parameters was 0.012331247329711914 for key π_gamma_col_3_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 6:  -37111.94614890645
# INFO:splink.iterate:Iteration 6 complete
# INFO:splink.params:The maximum change in parameters was 0.009450376033782959 for key π_gamma_col_3_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 7:  -37106.75426138064
# INFO:splink.iterate:Iteration 7 complete
# INFO:splink.params:The maximum change in parameters was 0.007376760244369507 for key π_gamma_col_3_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 8:  -37103.48863844625
# INFO:splink.iterate:Iteration 8 complete
# INFO:splink.params:The maximum change in parameters was 0.005835473537445068 for key π_gamma_col_3_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 9:  -37101.37740970857
# INFO:splink.iterate:Iteration 9 complete
# INFO:splink.params:The maximum change in parameters was 0.004663825035095215 for key π_gamma_col_3_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 10:  -37099.97142851008
# INFO:splink.iterate:Iteration 10 complete
# INFO:splink.params:The maximum change in parameters was 0.003758370876312256 for key π_gamma_col_3_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 11:  -37099.01446895318
# INFO:splink.iterate:Iteration 11 complete
# INFO:splink.params:The maximum change in parameters was 0.003049328923225403 for key π_gamma_col_3_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 12:  -37098.34321012703
# INFO:splink.iterate:Iteration 12 complete
# INFO:splink.params:The maximum change in parameters was 0.002487778663635254 for key π_gamma_col_3_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 13:  -37097.86472473072
# INFO:splink.iterate:Iteration 13 complete
# INFO:splink.params:The maximum change in parameters was 0.00203859806060791 for key π_gamma_col_3_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 14:  -37097.50920929166
# INFO:splink.iterate:Iteration 14 complete
# INFO:splink.params:The maximum change in parameters was 0.0016762465238571167 for key π_gamma_col_3_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 15:  -37097.241522893586
# INFO:splink.iterate:Iteration 15 complete
# INFO:splink.params:The maximum change in parameters was 0.0013818740844726562 for key π_gamma_col_3_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 16:  -37097.02893741601
# INFO:splink.iterate:Iteration 16 complete
# INFO:splink.params:The maximum change in parameters was 0.0011411160230636597 for key π_gamma_col_3_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 17:  -37096.859846973086
# INFO:splink.iterate:Iteration 17 complete
# INFO:splink.params:The maximum change in parameters was 0.0009432435035705566 for key π_gamma_col_3_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 18:  -37096.71951533742
# INFO:splink.iterate:Iteration 18 complete
# INFO:splink.params:The maximum change in parameters was 0.0007797777652740479 for key π_gamma_col_3_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 19:  -37096.5957595065
# INFO:splink.iterate:Iteration 19 complete
# INFO:splink.params:The maximum change in parameters was 0.0006900206208229065 for key π_gamma_col_4_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 20:  -37096.488110398794
# INFO:splink.iterate:Iteration 20 complete
# INFO:splink.params:The maximum change in parameters was 0.0006961226463317871 for key π_gamma_col_4_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 21:  -37096.3924111964
# INFO:splink.iterate:Iteration 21 complete
# INFO:splink.params:The maximum change in parameters was 0.0007011890411376953 for key π_gamma_col_4_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 22:  -37096.30194203298
# INFO:splink.iterate:Iteration 22 complete
# INFO:splink.params:The maximum change in parameters was 0.0007051825523376465 for key π_gamma_col_4_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 23:  -37096.21857332192
# INFO:splink.iterate:Iteration 23 complete
# INFO:splink.params:The maximum change in parameters was 0.0007080696523189545 for key π_gamma_col_4_prob_dist_non_match_level_1_probability
# INFO:splink.expectation_step:Log likelihood for iteration 24:  -37096.13955503995
# INFO:splink.iterate:Iteration 24 complete
# INFO:splink.params:The maximum change in parameters was 0.0007098913192749023 for key π_gamma_col_4_prob_dist_non_match_level_0_probability
# INFO:splink.expectation_step:Log likelihood for iteration 25:  -37096.06568998853
#    match_probability unique_id_l unique_id_r  gamma_col_1  \
# 0             0.0506    cc8e1bf9    02a4c2a1            0
# 1             0.0506    9ae59505    06450471            0
# 2             0.0506    0915e334    2f226b72            0
# 3             0.0506    0463f328    4d161f05            0
# 4             0.0506    30009c84    4952422d            0
#
#    prob_gamma_col_1_non_match  prob_gamma_col_1_match  gamma_col_2  \
# 0                      0.2705                  0.1022            1
# 1                      0.2705                  0.1022            1
# 2                      0.2705                  0.1022            1
# 3                      0.2705                  0.1022            1
# 4                      0.2705                  0.1022            1
#
#    prob_gamma_col_2_non_match  prob_gamma_col_2_match  gamma_col_3  \
# 0                      0.4083                  0.9473            0
# 1                      0.4083                  0.9473            0
# 2                      0.4083                  0.9473            0
# 3                      0.4083                  0.9473            0
# 4                      0.4083                  0.9473            0
#
#    prob_gamma_col_3_non_match  prob_gamma_col_3_match  gamma_col_4  \
# 0                      0.7558                  0.2036            0
# 1                      0.7558                  0.2036            0
# 2                      0.7558                  0.2036            0
# 3                      0.7558                  0.2036            0
# 4                      0.7558                  0.2036            0
#
#    prob_gamma_col_4_non_match  prob_gamma_col_4_match  true_match_l  \
# 0                      0.9748                  0.0339             1
# 1                      0.9748                  0.0339             1
# 2                      0.9748                  0.0339             1
# 3                      0.9748                  0.0339             1
# 4                      0.9748                  0.0339             1
#
#    true_match_r
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
linker.params
# Out:
# λ (proportion of matches) = 0.8663036227226257
# ------------------------------------
# gamma_col_1: Comparison of col_1
#
# Probability distribution of gamma values amongst matches:
#     value 0: 0.102230 (level represents lowest category of string similarity)
#     value 1: 0.897770 (level represents highest category of string similarity)
#
# Probability distribution of gamma values amongst non-matches:
#     value 0: 0.270495 (level represents lowest category of string similarity)
#     value 1: 0.729505 (level represents highest category of string similarity)
# ------------------------------------
# gamma_col_2: Comparison of col_2
#
# Probability distribution of gamma values amongst matches:
#     value 0: 0.052661 (level represents lowest category of string similarity)
#     value 1: 0.947339 (level represents highest category of string similarity)
#
# Probability distribution of gamma values amongst non-matches:
#     value 0: 0.591683 (level represents lowest category of string similarity)
#     value 1: 0.408317 (level represents highest category of string similarity)
# ------------------------------------
# gamma_col_3: Comparison of col_3
#
# Probability distribution of gamma values amongst matches:
#     value 0: 0.203643 (level represents lowest category of string similarity)
#     value 1: 0.796357 (level represents highest category of string similarity)
#
# Probability distribution of gamma values amongst non-matches:
#     value 0: 0.755779 (level represents lowest category of string similarity)
#     value 1: 0.244221 (level represents highest category of string similarity)
# ------------------------------------
# gamma_col_4: Comparison of col_4
#
# Probability distribution of gamma values amongst matches:
#     value 0: 0.033942 (level represents lowest category of string similarity)
#     value 1: 0.966058 (level represents highest category of string similarity)
#
# Probability distribution of gamma values amongst non-matches:
#     value 0: 0.974849 (level represents lowest category of string similarity)
#     value 1: 0.025151 (level represents highest category of string similarity)

# %% [markdown]
# ### Example 2:  Esimtate only col_2, col_3 params

# %%
from copy import deepcopy
settings_3 = {
    "link_type": "dedupe_only",
    "proportion_of_matches":df_blocked["true_match_l"].mean(), 
    "comparison_columns": [
        {
            "col_name": "col_3",
            "m_probabilities": [0.2, 0.8],  # Probability of typo
            "u_probabilities": [0.8, 0.2],  # Probability of collision
        },
          {
            "col_name": "col_4",
            "m_probabilities": [0.05, 0.95],  # Probability of typo
            "u_probabilities": [0.9, 0.1],  # Probability of collision
        },
    ],
     "additional_columns_to_retain": [
        "true_match"
    ]
}

# %%
df_e, linker = estimate(df_blocked,deepcopy(settings_3),spark)
df_e.toPandas().head(5)
# Out:
# /Users/robinlinacre/anaconda3/lib/python3.8/site-packages/splink/case_statements.py:17: UserWarning: The jaro_winkler_sim user definined function is not available in Spark Or you did not pass 'spark' (the SparkSession) into 'Params' Falling back to using levenshtein in the default string comparison functions You can import these functions using the scala-udf-similarity-0.0.6.jar provided with Splink
#   warnings.warn(f"The jaro_winkler_sim user definined function is not available in Spark "
# INFO:splink.expectation_step:Log likelihood for iteration 0:  -22276.91616396846
# INFO:splink.iterate:Iteration 0 complete
# INFO:splink.params:The maximum change in parameters was 2.384185793236071e-08 for key π_gamma_col_4_prob_dist_non_match_level_0_probability
# INFO:splink.iterate:EM algorithm has converged
# INFO:splink.expectation_step:Log likelihood for iteration 1:  -22276.916111814535
#    match_probability unique_id_l unique_id_r  gamma_col_3  \
# 0             0.0857    cc8e1bf9    02a4c2a1            0
# 1             0.0857    9ae59505    06450471            0
# 2             0.0857    0915e334    2f226b72            0
# 3             0.0857    0463f328    4d161f05            0
# 4             0.0857    30009c84    4952422d            0
#
#    prob_gamma_col_3_non_match  prob_gamma_col_3_match  gamma_col_4  \
# 0                      0.8000                  0.2000            0
# 1                      0.8000                  0.2000            0
# 2                      0.8000                  0.2000            0
# 3                      0.8000                  0.2000            0
# 4                      0.8000                  0.2000            0
#
#    prob_gamma_col_4_non_match  prob_gamma_col_4_match  true_match_l  \
# 0                      0.9000                  0.0500             1
# 1                      0.9000                  0.0500             1
# 2                      0.9000                  0.0500             1
# 3                      0.9000                  0.0500             1
# 4                      0.9000                  0.0500             1
#
#    true_match_r
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1

# %%
linker.params
# Out:
# λ (proportion of matches) = 0.8708971738815308
# ------------------------------------
# gamma_col_3: Comparison of col_3
#
# Probability distribution of gamma values amongst matches:
#     value 0: 0.200000 (level represents lowest category of string similarity)
#     value 1: 0.800000 (level represents highest category of string similarity)
#
# Probability distribution of gamma values amongst non-matches:
#     value 0: 0.800000 (level represents lowest category of string similarity)
#     value 1: 0.200000 (level represents highest category of string similarity)
# ------------------------------------
# gamma_col_4: Comparison of col_4
#
# Probability distribution of gamma values amongst matches:
#     value 0: 0.050000 (level represents lowest category of string similarity)
#     value 1: 0.950000 (level represents highest category of string similarity)
#
# Probability distribution of gamma values amongst non-matches:
#     value 0: 0.900000 (level represents lowest category of string similarity)
#     value 1: 0.100000 (level represents highest category of string similarity)
